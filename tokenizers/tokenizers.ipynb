# %%
from transformers import BertModel , AutoTokenizer
import pandas as pd 
import requests

# %% [markdown]
# yogh yaw

# %%
model_name ="bert-base-uncased"

# %%
# Instantiate the model and tokenizer for the specified pre-trained model
model = BertModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

tokenizer
# Out:
# c:\Users\cengh\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# BertTokenizerFast(name_or_path='bert-base-uncased', vocab_size=30522, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	100: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	101: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	102: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	103: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
sentence = " when life gives you lemons,dont make lemonade"
tokens = tokenizer.tokenize(sentence)
tokens
# Out:
# ['when',
#  'life',
#  'gives',
#  'you',
#  'lemon',
#  '##s',
#  ',',
#  'don',
#  '##t',
#  'make',
#  'lemon',
#  '##ade']

# %%
vocab = tokenizer.vocab
vocab
# Out:
# {'wildly': 13544,
#  'parapet': 27372,
#  'mathew': 25436,
#  'officer': 2961,
#  '1823': 12522,
#  'tasted': 12595,
#  'princely': 22771,
#  '##strel': 26877,
#  'johnnie': 27716,
#  'entries': 10445,
#  '##cian': 14483,
#  'kennedy': 5817,
#  'genuinely': 15958,
#  'flipping': 18497,
#  'reorganized': 14137,
#  'enrico': 21982,
#  '##main': 24238,
#  'reminding': 15906,
#  'aired': 4836,
#  'knocks': 21145,
#  '[unused849]': 854,
#  'snorted': 15235,
#  'pol': 14955,
#  'daisy': 10409,
#  '##♠': 30150,
#  'extremely': 5186,
#  'varying': 9671,
#  'خ': 1277,
#  'accountable': 26771,
#  'depot': 8470,
#  'observation': 8089,
#  'syndication': 26973,
#  'creamy': 24519,
#  'forgotten': 6404,
#  'se': 7367,
#  '##25': 17788,
#  'jang': 23769,
#  'transitioned': 23946,
#  'anglia': 24217,
#  'lowered': 6668,
#  '[unused244]': 249,
#  'items': 5167,
#  'wizards': 16657,
#  'weep': 27874,
#  '##pw': 28400,
#  'jonny': 26937,
#  'chevy': 29009,
#  'gland': 25320,
#  '##ner': 3678,
#  '800': 5385,
#  '[unused571]': 576,
#  'graduating': 6800,
#  'pastor': 9220,
#  '##tag': 15900,
#  'benefits': 6666,
#  'flare': 17748,
#  'cruisers': 16722,
#  'dryly': 20825,
#  'km²': 3186,
#  'readings': 15324,
#  '##wine': 21924,
#  'harlan': 24276,
#  'wan': 14071,
#  'staggering': 26233,
#  'prem': 26563,
#  'plumbing': 27902,
#  'brit': 28101,
#  '##ciency': 29125,
#  'portland': 6734,
#  '##tv': 9189,
#  'fears': 10069,
#  '十': 1783,
#  'cutter': 16343,
#  'compelling': 17075,
#  '##som': 25426,
#  '##g': 2290,
#  'guillaume': 20061,
#  'communal': 15029,
#  'extant': 12905,
#  '##music': 27275,
#  'case': 2553,
#  'performer': 9256,
#  '##oo': 9541,
#  'vice': 3580,
#  'garrison': 8427,
#  'instability': 18549,
#  '##onus': 24891,
#  'dominated': 6817,
#  '##vale': 17479,
#  '145': 13741,
#  'turkmenistan': 25432,
#  'affairs': 3821,
#  'pisa': 25472,
#  'movement': 2929,
#  'medicines': 20233,
#  '[unused167]': 172,
#  'generals': 11593,
#  'dizzy': 14849,
#  'finished': 2736,
#  'campaigns': 8008,
#  'austrians': 28439,
#  '[unused780]': 785,
#  'zimbabwe': 11399,
#  'pajamas': 27621,
#  'jim': 3958,
#  'roberta': 23455,
#  'socks': 14829,
#  'convey': 16636,
#  'winged': 14462,
#  'placement': 11073,
#  'violence': 4808,
#  'decreases': 17913,
#  'gather': 8587,
#  'denomination': 18683,
#  'formulas': 25814,
#  'sculptors': 28417,
#  'ₗ': 1566,
#  'fragmented': 26872,
#  'windsor': 10064,
#  '1766': 21410,
#  'whipping': 23016,
#  '##ﬁ': 30510,
#  '##torm': 20654,
#  'cradled': 23774,
#  'snacks': 27962,
#  '##ian': 2937,
#  'johannes': 12470,
#  'amir': 18904,
#  'basque': 13915,
#  'erik': 10240,
#  'novice': 23131,
#  '##¨': 29651,
#  'smelled': 9557,
#  'bill': 3021,
#  'gun': 3282,
#  'tin': 9543,
#  'announcements': 25674,
#  'oral': 8700,
#  'portrayed': 6791,
#  'kendra': 13812,
#  'lucius': 15639,
#  'excluded': 12421,
#  '##nais': 28020,
#  'reporters': 12060,
#  '##oj': 29147,
#  'mace': 19382,
#  'psalms': 26130,
#  'britten': 29429,
#  'realization': 12393,
#  'frank': 3581,
#  'panel': 5997,
#  'clarified': 20485,
#  'july': 2251,
#  '##心': 30375,
#  'turbines': 17396,
#  '[unused422]': 427,
#  'stream': 5460,
#  'beaux': 20290,
#  '##essed': 23656,
#  'san': 2624,
#  'presents': 7534,
#  'pam': 14089,
#  'craters': 27561,
#  'efficiency': 8122,
#  '##dim': 22172,
#  'loaned': 13190,
#  'cornell': 10921,
#  'goodwill': 22875,
#  'arrests': 17615,
#  'shipyard': 13858,
#  'grandson': 7631,
#  '##xa': 18684,
#  '##scia': 27210,
#  'compromised': 20419,
#  '##ف': 29833,
#  '##≤': 30135,
#  'ebony': 27680,
#  'dam': 5477,
#  'plank': 24000,
#  'practised': 20439,
#  'physically': 8186,
#  'crowns': 24364,
#  'rubbed': 7503,
#  '195': 17317,
#  'perception': 10617,
#  'playhouse': 17408,
#  'mcdonnell': 23149,
#  'detonated': 28110,
#  'neat': 15708,
#  'incurred': 22667,
#  '##pressed': 19811,
#  'textual': 25304,
#  'nobleman': 18487,
#  '404': 24837,
#  'mountainous': 14897,
#  'embark': 28866,
#  'citrus': 20418,
#  'greyish': 26916,
#  '##urrent': 29264,
#  'vitro': 25714,
#  '##ร': 29953,
#  'preceding': 11003,
#  'queensland': 5322,
#  'electrification': 23679,
#  '##56': 26976,
#  'ligand': 27854,
#  'longitudinal': 20134,
#  'gaul': 26522,
#  '##rts': 21217,
#  '##،': 29814,
#  'towed': 18948,
#  'sas': 21871,
#  '##lk': 13687,
#  'dempsey': 28165,
#  '[unused795]': 800,
#  'goddess': 7804,
#  'shiva': 12535,
#  'ethnicity': 18240,
#  'raion': 24235,
#  'trails': 9612,
#  'rejoin': 25261,
#  '##anian': 26032,
#  '##љ': 29762,
#  '##aly': 20766,
#  '##tham': 22536,
#  'evolutionary': 12761,
#  '##ump': 24237,
#  'bunk': 25277,
#  '##gf': 25708,
#  '##cock': 13959,
#  '##around': 24490,
#  '580': 23712,
#  'sideways': 12579,
#  'extracts': 27059,
#  'accidents': 13436,
#  'circular': 8206,
#  'adaptation': 6789,
#  'railway': 2737,
#  '##dh': 16425,
#  '##ene': 8625,
#  'sword': 4690,
#  '[unused539]': 544,
#  '##合': 30318,
#  '##ʒ': 29704,
#  'mandarin': 15831,
#  '1620': 24259,
#  '##lander': 22691,
#  'kidd': 25358,
#  '##nche': 26091,
#  '##leg': 23115,
#  'extinction': 14446,
#  'federation': 4657,
#  'flap': 20916,
#  'inquisition': 24638,
#  'tomorrow': 4826,
#  'subjective': 20714,
#  'parallels': 18588,
#  'umar': 27981,
#  'carpenter': 10533,
#  'glee': 18874,
#  'translating': 22969,
#  'stores': 5324,
#  'celaena': 29252,
#  'reins': 19222,
#  'fiba': 13651,
#  'osborn': 26999,
#  'cheltenham': 18763,
#  'employees': 5126,
#  'tab': 21628,
#  'escaping': 13002,
#  'technician': 16661,
#  'ragged': 14202,
#  'noun': 15156,
#  'tests': 5852,
#  'proof': 6947,
#  'treatments': 13441,
#  '[unused207]': 212,
#  'dismay': 20006,
#  'entering': 5738,
#  'pigs': 14695,
#  'flew': 5520,
#  'inadvertently': 21089,
#  '1977': 3355,
#  'commendation': 23039,
#  'convergence': 19143,
#  'depression': 6245,
#  'vial': 28475,
#  'reactions': 9597,
#  'dame': 8214,
#  '##borg': 11755,
#  'salvatore': 17485,
#  'eileen': 20495,
#  'mighty': 10478,
#  'reach': 3362,
#  'nineteenth': 9137,
#  'annoying': 15703,
#  'priscilla': 25193,
#  '##wley': 20609,
#  'thompson': 5953,
#  'steamship': 23869,
#  'mri': 27011,
#  'trinity': 7124,
#  '##英': 30467,
#  'bowman': 19298,
#  'propulsion': 16404,
#  'habit': 10427,
#  'sculptures': 10801,
#  'advance': 5083,
#  'isa': 18061,
#  'sight': 4356,
#  'previous': 3025,
#  'sandstone': 11694,
#  'blanche': 18158,
#  'astronomical': 13674,
#  'parisian': 24262,
#  '22': 2570,
#  'fixed': 4964,
#  'silvery': 21666,
#  'evan': 9340,
#  'flyer': 23821,
#  'may': 2089,
#  'honestly': 9826,
#  'postponed': 14475,
#  '##box': 8758,
#  '##cise': 18380,
#  'ellis': 8547,
#  'servers': 14903,
#  'gradient': 17978,
#  '132': 14078,
#  'matthews': 12351,
#  'relocate': 20102,
#  '1935': 4437,
#  '##bone': 14417,
#  'forearm': 16148,
#  'crank': 27987,
#  'tully': 25724,
#  'donated': 6955,
#  'stared': 3592,
#  'suppression': 16341,
#  'sizable': 25908,
#  'comfort': 7216,
#  '##skin': 29334,
#  'hangs': 17991,
#  'demos': 18267,
#  '[unused198]': 203,
#  'shift': 5670,
#  'lawsuit': 9870,
#  '##т': 22919,
#  'trumpeter': 28220,
#  'beyonce': 20773,
#  'overtime': 12253,
#  'manipulation': 16924,
#  'autonomous': 8392,
#  '##ⁿ': 30080,
#  'millionaire': 19965,
#  'potentially': 9280,
#  'tribunal': 12152,
#  'discreet': 29321,
#  '##ᅲ': 30016,
#  '##sett': 21678,
#  '一': 1740,
#  'publishes': 12466,
#  'pickup': 15373,
#  'nr': 17212,
#  'seconds': 3823,
#  'maximal': 29160,
#  'talmud': 24380,
#  'judah': 23022,
#  'university': 2118,
#  'freaking': 13847,
#  'settles': 27221,
#  'ollie': 25208,
#  'borg': 28709,
#  'purchases': 17402,
#  '##dating': 16616,
#  'rematch': 18229,
#  '"': 1000,
#  '##par': 19362,
#  'busch': 15840,
#  '151': 16528,
#  '（': 1987,
#  'leadership': 4105,
#  'ghana': 9701,
#  'downstairs': 10025,
#  'visiting': 5873,
#  'warned': 7420,
#  'rann': 26312,
#  '##村': 30404,
#  'segregation': 18771,
#  '##rangle': 21476,
#  'fastened': 24009,
#  'shear': 18330,
#  'rammed': 27653,
#  'rocket': 7596,
#  'য': 1371,
#  '##chs': 18069,
#  'monks': 9978,
#  '##sville': 9337,
#  'missions': 6416,
#  '##nese': 14183,
#  '##伊': 30288,
#  'number': 2193,
#  'everything': 2673,
#  'stood': 2768,
#  '[unused969]': 974,
#  'motto': 12652,
#  'cornerback': 26857,
#  'choosing': 10549,
#  'plug': 13354,
#  'virginity': 26970,
#  '##yk': 15922,
#  'ᶠ': 1512,
#  'describe': 6235,
#  'summon': 18654,
#  'ass': 4632,
#  'achieve': 6162,
#  'worshipped': 22876,
#  'gloom': 24067,
#  '##ན': 29965,
#  'playboy': 18286,
#  '##tens': 25808,
#  '##nig': 25518,
#  'couldn': 2481,
#  'becoming': 3352,
#  'sylvester': 20016,
#  'fitted': 7130,
#  '##lie': 8751,
#  'mid': 3054,
#  'gamma': 13091,
#  'whatever': 3649,
#  'saudi': 8174,
#  'desert': 5532,
#  'fighter': 4959,
#  '##lb': 20850,
#  'utilize': 16462,
#  'sacrifices': 18502,
#  'donate': 21357,
#  'improper': 24156,
#  'industrialist': 21691,
#  'circumstance': 25652,
#  'critically': 11321,
#  'appealed': 12068,
#  'futures': 17795,
#  'sadly': 13718,
#  'series': 2186,
#  '[unused562]': 567,
#  '##azi': 16103,
#  'tq': 28816,
#  'billy': 5006,
#  'genetics': 14471,
#  'moth': 5820,
#  'adverse': 15316,
#  'investigates': 28062,
#  '##cula': 19879,
#  'blackout': 26717,
#  'explosions': 18217,
#  'azerbaijan': 8365,
#  'mercury': 8714,
#  'mcguire': 23872,
#  'jurisprudence': 24697,
#  'pistol': 8779,
#  'abroad': 6917,
#  'noteworthy': 19144,
#  'closely': 4876,
#  'fairfax': 17833,
#  'sarah': 4532,
#  'excavation': 16456,
#  '[unused559]': 564,
#  'precise': 10480,
#  '##pathy': 20166,
#  'pokemon': 20421,
#  'object': 4874,
#  '##esh': 9953,
#  'millimetres': 13388,
#  'rana': 22175,
#  'ports': 8831,
#  'template': 23561,
#  '##erved': 25944,
#  '##eet': 15558,
#  '[unused640]': 645,
#  '[unused556]': 561,
#  'houghton': 21234,
#  '##য': 29907,
#  'adolescent': 20274,
#  '##beam': 28302,
#  '##এ': 29887,
#  'フ': 1720,
#  'claudius': 25017,
#  'proton': 20843,
#  'uncles': 27328,
#  'admiring': 24588,
#  'austria': 5118,
#  'insurgents': 20541,
#  'grew': 3473,
#  'croats': 26222,
#  '[unused183]': 188,
#  'ara': 19027,
#  'scout': 7464,
#  'definition': 6210,
#  'talon': 19048,
#  'decay': 13121,
#  'favors': 21191,
#  'forceful': 28552,
#  'robyn': 28047,
#  'subject': 3395,
#  'drones': 24633,
#  'connect': 7532,
#  'treasures': 17605,
#  'pharmaceuticals': 24797,
#  'atp': 12649,
#  'responsibility': 5368,
#  '##х': 29750,
#  'monumental': 15447,
#  '%': 1003,
#  'accused': 5496,
#  'ported': 27650,
#  'eligible': 7792,
#  'zulu': 27359,
#  '##lder': 16502,
#  '##ched': 7690,
#  'mana': 24951,
#  'scowled': 17474,
#  'shri': 14880,
#  'bakery': 18112,
#  '##м': 29745,
#  'offspring': 13195,
#  'populations': 7080,
#  'pulpit': 23134,
#  'hilary': 22744,
#  'grooves': 25880,
#  'asleep': 6680,
#  'motel': 14901,
#  'concept': 4145,
#  'demands': 7670,
#  '1772': 17483,
#  'sworn': 10741,
#  'cattle': 7125,
#  'boogie': 21495,
#  'dent': 21418,
#  '##aurus': 17342,
#  'philosophical': 9569,
#  '##場': 30332,
#  'district': 2212,
#  'apocalypse': 16976,
#  'ensures': 21312,
#  'removed': 3718,
#  '##bib': 28065,
#  'paved': 12308,
#  'increasing': 4852,
#  '##r': 2099,
#  'oval': 9242,
#  '[unused498]': 503,
#  'scorpion': 22015,
#  'zagreb': 12974,
#  'beyond': 3458,
#  'visitation': 28877,
#  'originate': 21754,
#  'distal': 29333,
#  'medallist': 28595,
#  '##mata': 21022,
#  'plata': 19534,
#  'hue': 20639,
#  'aggregator': 24089,
#  '[unused22]': 23,
#  'anand': 18887,
#  '##司': 30317,
#  'champion': 3410,
#  'andersson': 28643,
#  '[unused581]': 586,
#  'naia': 29511,
#  '1656': 28434,
#  'snowy': 20981,
#  'mayfield': 27224,
#  'malibu': 29047,
#  'prestige': 14653,
#  '##fb': 26337,
#  '##分': 30301,
#  'seed': 6534,
#  'tickets': 9735,
#  'citizen': 6926,
#  'employs': 13495,
#  'warsaw': 8199,
#  '##pus': 12207,
#  '京': 1755,
#  'amelie': 25285,
#  '[unused435]': 440,
#  '##iving': 14966,
#  'overrun': 24672,
#  'agony': 12812,
#  'pegasus': 26606,
#  'targets': 7889,
#  'monaco': 14497,
#  'color': 3609,
#  'brandon': 8825,
#  'outraged': 23558,
#  'horatio': 27752,
#  'ferguson': 11262,
#  '[unused698]': 703,
#  'greenwood': 16827,
#  'ceremony': 5103,
#  'treatise': 15326,
#  '##pment': 24073,
#  'feedback': 12247,
#  '23': 2603,
#  'shrill': 28349,
#  'behind': 2369,
#  'or': 2030,
#  'analog': 11698,
#  'malone': 16321,
#  'mongol': 17450,
#  'narrowly': 11866,
#  'supposedly': 10743,
#  'projections': 21796,
#  'half': 2431,
#  'plunging': 29059,
#  'seaside': 20276,
#  '##dad': 14697,
#  '辶': 1956,
#  'staircase': 10714,
#  'criterion': 19229,
#  'grimly': 22561,
#  '##shire': 7430,
#  'principality': 18018,
#  'colourful': 26102,
#  '##plicity': 27293,
#  '##kley': 22315,
#  'refugee': 13141,
#  'trailers': 21389,
#  'garrett': 9674,
#  '##atus': 15590,
#  '##nger': 11392,
#  'nitrate': 29607,
#  'mars': 7733,
#  'biographer': 17121,
#  'rs': 12667,
#  'io': 22834,
#  '[unused938]': 943,
#  '##tus': 5809,
#  '##hl': 7317,
#  '##llin': 21202,
#  'org': 8917,
#  '[unused846]': 851,
#  '##enne': 24336,
#  'skyline': 21343,
#  'exemplary': 27792,
#  'gilles': 21717,
#  'iss': 26354,
#  'gabrielle': 16988,
#  '##ச': 29919,
#  'futuristic': 28971,
#  'skiing': 12701,
#  'harsh': 8401,
#  'lambert': 12838,
#  'insurrection': 27860,
#  'exclusion': 15945,
#  'newfoundland': 11944,
#  'knots': 9439,
#  'confederation': 11078,
#  'trough': 23389,
#  'surely': 7543,
#  'slavery': 8864,
#  'printer': 15041,
#  'georg': 12062,
#  '1757': 22621,
#  'honors': 7836,
#  'graffiti': 17990,
#  '##₄': 17004,
#  '⊕': 1612,
#  'sampling': 16227,
#  '##hong': 19991,
#  '##29': 24594,
#  'ต': 1411,
#  'aero': 18440,
#  'orton': 25161,
#  'bilbao': 25427,
#  'haryana': 23261,
#  '##lewood': 26580,
#  '##uously': 28078,
#  'barbarians': 28056,
#  'threatens': 17016,
#  'domed': 29208,
#  'redesignated': 11836,
#  'barr': 19820,
#  'ar': 12098,
#  'involves': 7336,
#  '##ndon': 19333,
#  'depends': 9041,
#  '1944': 3646,
#  '##eral': 21673,
#  '##pace': 15327,
#  '##tase': 18260,
#  'dawson': 11026,
#  'remains': 3464,
#  'centres': 8941,
#  'backwards': 11043,
#  'ramirez': 15206,
#  'rockets': 12496,
#  'cent': 9358,
#  '451': 28161,
#  'spouse': 18591,
#  'purple': 6379,
#  'flies': 10029,
#  'costing': 22173,
#  'cellular': 12562,
#  '##dick': 24066,
#  'rug': 20452,
#  'distinguished': 5182,
#  'caliphate': 28034,
#  '##biology': 21685,
#  '##ishly': 19983,
#  '##ほ': 30202,
#  'overdose': 26641,
#  '##nare': 26148,
#  'demons': 7942,
#  'referencing': 28789,
#  'վ': 1235,
#  'determine': 5646,
#  'donation': 13445,
#  'bernardo': 21175,
#  '##ᵀ': 30031,
#  'ranged': 15844,
#  'salesman': 18968,
#  'oven': 17428,
#  'kendrick': 25341,
#  '1826': 11931,
#  'web': 4773,
#  'faculties': 18658,
#  'olga': 15585,
#  'juniper': 29425,
#  '##yuki': 19663,
#  '##wark': 24298,
#  'impairment': 25172,
#  'bruno': 10391,
#  'strangers': 12358,
#  'minimize': 18478,
#  'sable': 23492,
#  'lover': 7089,
#  'trainee': 26758,
#  'footage': 8333,
#  'tango': 17609,
#  'fluctuations': 28892,
#  'members': 2372,
#  '##ர': 29927,
#  'nasal': 19077,
#  'accurately': 14125,
#  'res': 24501,
#  '##tones': 11115,
#  'woken': 22795,
#  'consonant': 18265,
#  '##veda': 28614,
#  '##drik': 28730,
#  'deal': 3066,
#  'witness': 7409,
#  'incorrect': 16542,
#  'virtue': 11870,
#  'retracted': 28214,
#  '##rell': 16230,
#  'donna': 10972,
#  'gaga': 23332,
#  '[unused160]': 165,
#  '##յ': 29777,
#  'pounding': 9836,
#  'reformed': 9114,
#  'פ': 1261,
#  '1634': 28502,
#  'ac': 9353,
#  'lynch': 11404,
#  'quivering': 26012,
#  'plate': 5127,
#  'firstly': 15847,
#  'aug': 15476,
#  'clocks': 20940,
#  '##ground': 16365,
#  'til': 18681,
#  'framed': 10366,
#  '##plin': 28296,
#  '##∗': 30125,
#  'plantations': 14979,
#  'reconciliation': 16088,
#  'bequeathed': 27180,
#  'hundreds': 5606,
#  'programs': 3454,
#  'marcia': 22548,
#  '##des': 6155,
#  'archer': 11024,
#  'disapproval': 21406,
#  '##mara': 28225,
#  'rushes': 18545,
#  'assertion': 23617,
#  'residing': 7154,
#  '##gas': 12617,
#  'cyclists': 21912,
#  '##pe': 5051,
#  'kaiser': 15676,
#  'amplitude': 22261,
#  'mated': 28795,
#  '[unused688]': 693,
#  '[unused454]': 459,
#  '##mart': 22345,
#  'prone': 13047,
#  'instructions': 8128,
#  'ᴵ': 1493,
#  'squash': 18794,
#  '##tric': 12412,
#  'iucn': 20333,
#  'neighbours': 14754,
#  'jen': 15419,
#  'leap': 11679,
#  'kara': 13173,
#  'buzzing': 20386,
#  'heightened': 21106,
#  'richmond': 6713,
#  '##tan': 5794,
#  'nigerian': 11884,
#  'napoli': 29485,
#  '60s': 20341,
#  'niccolo': 27033,
#  'unlimited': 14668,
#  'legendary': 8987,
#  'hitch': 27738,
#  '##koff': 26126,
#  '[unused812]': 817,
#  'blanc': 18698,
#  'pointless': 23100,
#  'influence': 3747,
#  'steady': 6706,
#  'fielded': 20988,
#  'silly': 10021,
#  '##ια': 27432,
#  '##uation': 14505,
#  'lai': 21110,
#  'specializing': 14055,
#  'correlation': 16902,
#  '##nging': 22373,
#  'acknowledges': 28049,
#  'simulcast': 20525,
#  'comprise': 15821,
#  'megan': 12756,
#  '1874': 7586,
#  'lodged': 20451,
#  '##la': 2721,
#  'albany': 10283,
#  'mortals': 23844,
#  '##ﬂ': 30511,
#  'navigator': 20532,
#  'distance': 3292,
#  'restaurants': 7884,
#  'muzzle': 17750,
#  'sense': 3168,
#  'meyrick': 15228,
#  '##chfield': 22693,
#  '##etz': 26327,
#  'composers': 9929,
#  'holy': 4151,
#  'exodus': 16388,
#  '##ք': 29786,
#  'b': 1038,
#  'ox': 23060,
#  'losses': 6409,
#  '##華': 30468,
#  'trenches': 19874,
#  'bringing': 5026,
#  'clutches': 29497,
#  '##wi': 9148,
#  'holmes': 9106,
#  '##ganj': 22738,
#  '##國': 30326,
#  'friction': 15012,
#  '##ntly': 20630,
#  'admiral': 5902,
#  'hamid': 24811,
#  'leslie': 8886,
#  '##erre': 28849,
#  'unitary': 22127,
#  'lobby': 9568,
#  'spanning': 13912,
#  'scholastic': 24105,
#  'flourishing': 29571,
#  'excelled': 23081,
#  'bach': 10384,
#  'tempting': 23421,
#  'funny': 6057,
#  'shropshire': 19322,
#  'connection': 4434,
#  'nrhp': 22424,
#  'organize': 10939,
#  'banged': 22843,
#  '##istles': 28738,
#  'managers': 10489,
#  'σ': 1173,
#  'casa': 14124,
#  'doctrines': 23252,
#  'marko': 28003,
#  'hoffman': 15107,
#  '317': 26628,
#  'posts': 8466,
#  '##lessness': 24913,
#  '##wara': 11872,
#  'brigham': 22727,
#  '177': 18118,
#  'shave': 27545,
#  'blazers': 28513,
#  'commanding': 7991,
#  'furiously': 20322,
#  '[unused150]': 155,
#  'participates': 17257,
#  'xx': 22038,
#  '1991': 2889,
#  'consecrated': 12299,
#  'authentication': 27280,
#  'basalt': 26343,
#  'gilbert': 7664,
#  '##寺': 30353,
#  'investigate': 8556,
#  'repetition': 23318,
#  'fails': 11896,
#  'turbulent': 22609,
#  'influenced': 5105,
#  '##gl': 23296,
#  'kannada': 13873,
#  '##rst': 12096,
#  'elias': 14579,
#  'california': 2662,
#  '##之': 30275,
#  'mortal': 9801,
#  'equivalence': 27841,
#  '[unused401]': 406,
#  'pp': 4903,
#  'nutritional': 28268,
#  'angrily': 14136,
#  '##un': 4609,
#  '##ress': 8303,
#  'monarchy': 12078,
#  'resentment': 20234,
#  'note': 3602,
#  'antarctic': 10227,
#  'gallant': 26984,
#  '[unused314]': 319,
#  'wired': 17502,
#  'tended': 11121,
#  '##finder': 23695,
#  '##eur': 11236,
#  '##tooth': 19392,
#  'console': 10122,
#  'educators': 19156,
#  'bundles': 26825,
#  'request': 5227,
#  'contestant': 10832,
#  'banana': 15212,
#  'hates': 16424,
#  'values': 5300,
#  'plight': 24525,
#  'hare': 14263,
#  'argument': 6685,
#  '陽': 1973,
#  '[unused696]': 701,
#  'naturalist': 19176,
#  '##fa': 7011,
#  'gaddafi': 28924,
#  'supervisor': 12366,
#  'hector': 10590,
#  'preferred': 6871,
#  '275': 17528,
#  '[unused224]': 229,
#  'sonora': 26647,
#  'smack': 21526,
#  '##under': 20824,
#  '[unused136]': 141,
#  'hapoel': 24208,
#  'nanjing': 21455,
#  'ρ': 1171,
#  'lester': 14131,
#  'bursts': 19239,
#  '##islaus': 25678,
#  'lifespan': 26462,
#  '##ou': 7140,
#  'vision': 4432,
#  'expenses': 11727,
#  'improve': 5335,
#  'gesellschaft': 27482,
#  'alternating': 15122,
#  'anatolia': 23747,
#  'hotel': 3309,
#  'craving': 26369,
#  'circus': 9661,
#  'weeks': 3134,
#  'seal': 7744,
#  'devout': 26092,
#  '##zar': 9057,
#  '##rred': 20529,
#  '##ander': 12243,
#  '##nel': 11877,
#  'sequence': 5537,
#  'settlement': 4093,
#  'athens': 7571,
#  'costly': 17047,
#  'cuthbert': 24583,
#  'stiffly': 27499,
#  '##bey': 19182,
#  'kit': 8934,
#  ...}

# %%
token_id = tokenizer.encode(sentence)
token_id
# Out:
# [101,
#  2043,
#  2166,
#  3957,
#  2017,
#  14380,
#  2015,
#  1010,
#  2123,
#  2102,
#  2191,
#  14380,
#  9648,
#  102]
